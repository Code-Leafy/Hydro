# %% [markdown]
# # Hydro — Universal Media Download Colab
#
# One cell. One file. A free media downloader served through a Cloudflare Quick Tunnel.
#
# 1. **Run the cell below.**
# 2. **Wait for the `HYDRO IS READY` banner** (~1 minute: dependencies, FFmpeg, and the tunnel install automatically).
# 3. **Open the `https://…trycloudflare.com` URL** in any browser, paste a link, pick a format, and download.
#
# > Educational use only — download media you own or have permission to save. Keep this cell running while you download.

# %%
# !wget -q -O main.py https://raw.githubusercontent.com/Code-Leafy/hydro/main/main.py
# !python main.py
